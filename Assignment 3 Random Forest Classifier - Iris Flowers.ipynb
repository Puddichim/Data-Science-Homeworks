# %% [markdown]
# # Introduction to Data Science
#
# <div class="alert alert-block alert-success">
# <b>Assignment 3: Random Forest Classifier - Iris Flowers
# </div>

# %%
#Import Libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn import tree
import matplotlib.pyplot as plt
import graphviz
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import random

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data= iris.data ,columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Question 1: Split the Dataset and Build a Random Forest Classifier.

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_df,iris.target, test_size=0.25)

# %%
model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %% [markdown]
# ### Question 2: Evaluate your model on the Test Set

# %%
predictx = model.predict(X_test)
confusion = confusion_matrix(y_test, predictx)
confusion
# Out:
# array([[13,  0,  0],
#        [ 0, 14,  1],
#        [ 0,  1,  9]], dtype=int64)

# %%
print(classification_report(y_test, predictx))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.93      0.93      0.93        15
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.95        38
#    macro avg       0.94      0.94      0.94        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# ### Question 3: Visualize a Single Tree with graphviz

# %%
fn=iris.feature_names
cn=iris.target_names
random_number = random.randint(0, 9)
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (5,5), dpi= 1600)
tree.plot_tree(model.estimators_[random_number],
               feature_names = fn, 
               class_names=cn,
               filled = True);
